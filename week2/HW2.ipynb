# %%
#note: these data are run with the first 1000 lines of the file
import numpy 
import matplotlib.pyplot as plt

f = open('/Users/cmdb/qbb2020-answers/week2/HW2.csv', 'r')

DP = []
MQM = []
AF = []
eff = []


count = 0

for i in f:
    if "#" in i:
        continue
    lines = i.rstrip('\n\r').split('\t')
    lines2=lines[7].split(';') 
    final_lines = lines[8].split(':') 
    DP_line = lines2[7]
    MQM_line = lines2[15]
    AF_line = lines2[3]
    snp_line =
    DP.append(DP_line[3:])
    MQM.append(MQM_line[4:])
    AF.append(AF_line[3:])
    if count >100:
        break
  
print(DP)
#len(ls)

f.close()
# Out:
# ['119', '119', '198', '47', '67', '125', '216', '201', '150', '8', '7', '13', '13', '82', '106', '49', '32', '29', '30', '26', '29', '27', '45', '37', '54', '54', '53', '39', '29', '29', '22', '24', '23', '22', '26', '32', '35', '28', '23', '33', '28', '23', '38', '38', '37', '35', '28', '20', '40', '29', '31', '30', '25', '24', '25', '22', '15', '16', '14', '18', '20', '29', '24', '25', '32', '38', '50', '53', '27', '41', '55', '57', '58', '45', '40', '40', '37', '45', '24', '36', '29', '48', '48', '66', '66', '43', '38', '38', '36', '61', '51', '70', '67', '67', '43', '45', '56', '50', '49', '51', '28', '42', '45', '46', '41', '35', '23', '20', '17', '22', '39', '41', '32', '32', '29', '26', '38', '35', '42', '48', '39', '36', '44', '25', '34', '35', '29', '20', '33', '45', '33', '32', '27', '33', '29', '25', '30', '29', '30', '42', '40', '42', '53', '34', '48', '59', '47', '40', '31', '32', '40', '49', '46', '41', '77', '74', '51', '48', '70', '55', '43', '54', '46', '46', '40', '
# ...

# %%
fig, ax = plt.subplots(3)
ax[0].hist(DP, bins=30)
ax[1].hist(MQM, bins=30)
ax[2].hist(AF, bins=30)

ax[0].set_xlabel('Depth Distribution')
ax[0].set_ylabel('Frequency')
ax[1].set_xlabel('Quality Distribution')
ax[1].set_ylabel('Frequency')
ax[2].set_xlabel('Allele Frequency Spectrum')
ax[2].set_ylabel('Frequency')
fig.tight_layout()

# %%
# unfortunately, I was not able to find an ID for the snpeff
