# %%
import scanpy as sc
# Read 10x dataset
adata = sc.read_10x_h5("/Users/cmdb/qbb2020answers2/week8/neuron_10k_v3_filtered_feature_bc_matrix.h5")
# Make variable names (in this case the genes) unique
adata.var_names_make_unique()
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /Users/cmdb/miniconda3/envs/week10/lib/python3.6/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
sc.tl.pca(adata)
sc.pl.pca(adata)
# Out:
# /Users/cmdb/miniconda3/envs/week10/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical

# %%
sc.pp.recipe_zheng17(adata)
sc.tl.pca(adata)
sc.pl.pca(adata)
# Out:
# /Users/cmdb/miniconda3/envs/week10/lib/python3.6/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# /Users/cmdb/miniconda3/envs/week10/lib/python3.6/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# /Users/cmdb/miniconda3/envs/week10/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])

# %%
sc.pp.neighbors(adata)
sc.tl.leiden(adata)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-38756b42370d> in <module>()
# ----> 1 print(leiden)
#
# NameError: name 'leiden' is not defined

# %%
sc.tl.tsne(adata)
sc.pl.tsne(adata, color = "leiden")
# Out:
# WARNING: Consider installing the package MulticoreTSNE (https://github.com/DmitryUlyanov/Multicore-TSNE). Even for n_jobs=1 this speeds up the computation considerably and might yield better converged results.
# /Users/cmdb/miniconda3/envs/week10/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])

# %%
sc.tl.umap(adata)
sc.pl.umap(adata, color = "leiden")
# Out:
# /Users/cmdb/miniconda3/envs/week10/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])

# %%
sc.tl.rank_genes_groups(adata, "leiden")
sc.pl.rank_genes_groups(adata)
# Out:
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# /Users/cmdb/miniconda3/envs/week10/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
# /Users/cmdb/miniconda3/envs/week10/lib/python3.6/site-packages/scanpy/tools/_rank_genes_groups.py:408: RuntimeWarning: invalid value encountered in log2
#   foldchanges[global_indices]

# %%
sc.tl.rank_genes_groups(adata, "leiden", method = "logreg")
sc.pl.rank_genes_groups(adata)
# Out:
# /Users/cmdb/miniconda3/envs/week10/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
# /Users/cmdb/miniconda3/envs/week10/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
#sc.pl.umap(adata, color=["Lsr", "Egfl7", "Maf", "Reln", "Ndnf", "Abcc9", "Vtn", "Cox4i2", "Cspg4","Hba-a1", "C1qa",  "C1qb", "Ighm",  "Grin2b", "Olig2", "Igfbp3", "Adarb2", "Gad1", "Prox1", "Sox2", "Nrxn3", "Nts", "Stmn2", "Islr2", "Slit3"])

# %%
sc.pl.umap(adata, color=["Ndnf", "Hba-a1", "Olig2", "C1qa", "Aldh1l1", "Cox4i2", "Lhx6", "Tac2"])
# Out:
# /Users/cmdb/miniconda3/envs/week10/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])

# %% [markdown]
# Ndnf - Cortical interneuron
# Hba-a1 - Red blood cell
# Olig2 - Oligodendrocyte
# C1qa - Microglia
# Aldh1l1 - Astrocyte
# Cox4i2 - Pericyte
# Lhx6 - Paravalbumin and somastatin interneuron (medial ganglion)
# Tac2 - DRG

# %%
new_names = ["Parvalbumin Interneuron","1","Microglia","3","4","5","6","7","Astrocyte","9","RBC","DRG","12","13","14","15","16","Oligodendrocyte","18","19","Cortical Interneuron","21","22","Pericyte","24","25"]
adata.rename_categories('leiden', new_names)
sc.tl.umap(adata)
sc.pl.umap(adata, color = "leiden")
# Out:
# /Users/cmdb/miniconda3/envs/week10/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
